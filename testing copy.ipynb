# %%
import pandas as pd
df = pd.read_csv("hemant.csv")
df.sample(10)
# Out:
#      Transaction Statement for 8540015748  \
# 536                  UTR No. 404074110874
# 958                               Paid by
# 1387                             05 15 pm
# 270                          Page 8 of 48
# 1133                              Paid by
# 1555                             07 06 pm
# 1002                             07 16 pm
# 126                               Paid by
# 1610                             09 10 pm
# 98                   UTR No. 409823110631
#
#                                   Unnamed: 1 Unnamed: 2 Unnamed: 3
# 536                                      NaN        NaN        NaN
# 958                               XXXXXX8350        NaN        NaN
# 1387  Transaction ID T2306281715329513711139        NaN        NaN
# 270                                      NaN        NaN        NaN
# 1133                              XXXXXX8350        NaN        NaN
# 1555  Transaction ID T2305291906064007148717        NaN        NaN
# ...

# %%
df.rename(columns={"Transaction Statement for 8540015748": "Datetime"}, inplace=True)
df.rename(columns={"Unnamed: 1": "Name"}, inplace=True)
df.rename(columns={"Unnamed: 2": "Type"}, inplace=True)
df.rename(columns={"Unnamed: 3": "Amount"}, inplace=True)
df.sample(10)
# Out:
#                   Datetime                                    Name   Type  \
# 240   UTR No. 444716204549                                     NaN    NaN
# 17                 Paid by                              XXXXXX8350    NaN
# 682                Paid by                              XXXXXX8350    NaN
# 407               08 56 pm  Transaction ID T2403012056506196075540    NaN
# 877           Dec 04, 2023   Paid to LITTLE CHEF FAMILY RESTAURANT  DEBIT
# 1092              09 19 pm  Transaction ID T2309122119177585800120    NaN
# 359           Mar 06, 2024                Paid to Bonfire Bakery K  DEBIT
# 1166              08 13 pm  Transaction ID T2308082013167347421632    NaN
# 27                08 35 am  Transaction ID T2404230834583933499113    NaN
# 839                Paid by                              XXXXXX8350    NaN
#
#      Amount
# 240     NaN
# 17      NaN
# 682     NaN
# 407     NaN
# 877    ₹277
# 1092    NaN
# 359     ₹80
# 1166    NaN
# 27      NaN
# 839     NaN

# %%
df.columns
# Out:
# Index(['Datetime', 'Name', 'Type', 'Amount'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1656 entries, 0 to 1655
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  1654 non-null   object
#  1   Name      1169 non-null   object
#  2   Type      421 non-null    object
#  3   Amount    421 non-null    object
# dtypes: object(4)
# memory usage: 51.9+ KB

# %%
df = df.dropna()
df.sample(10)
# Out:
#           Datetime                                        Name    Type  Amount
# 635   Jan 23, 2024                       Paid to Bajrang Fuels   DEBIT    ₹100
# 1582  May 15, 2023              Paid to Mr. AJAYA KUMAR BEHERA   DEBIT    ₹500
# 199   Mar 23, 2024                         Paid to DELHI CHAAT   DEBIT     ₹25
# 1141  Aug 12, 2023  Paid to TIRPURARI PANDEY SO LATE HARISHANK   DEBIT    ₹300
# 483   Feb 18, 2024                        Paid to Sukanta auto   DEBIT     ₹70
# 1543  May 29, 2023                           Received from Dad  CREDIT  ₹2,000
# 1157  Aug 10, 2023                     Paid to THE MUGS COFFEE   DEBIT     ₹60
# 1363  Jul 09, 2023                       Paid to Prabhat store   DEBIT    ₹365
# 1416          Date                         Transaction Details    Type  Amount
# 683   Jan 18, 2024                    Paid to MEDKART 24- FMCG   DEBIT    ₹105

# %%
df['Amount'] = df['Amount'].str.replace('₹', '')
df.sample(10)
# Out:
#           Datetime                            Name    Type  Amount
# 1421  Jun 10, 2023                         Paid to   DEBIT   1,100
# 1644  May 09, 2023        Paid to Kiit Harshvardan   DEBIT     150
# 1196  Aug 05, 2023        Paid to MEDKART 24- FMCG   DEBIT     192
# 1543  May 29, 2023               Received from Dad  CREDIT   2,000
# 534   Feb 09, 2024            Paid to ARBIND KUMAR   DEBIT     100
# 762   Jan 09, 2024               Received from Mom  CREDIT   2,000
# 690   Jan 18, 2024       Paid to Burger King India   DEBIT  364.36
# 1262  Jul 27, 2023          Paid to LOKANATH SAHOO   DEBIT      30
# 651   Jan 21, 2024  Paid to Wow Momo Infocity BBSR   DEBIT     145
# 1570  May 15, 2023               Received from Mom  CREDIT   1,000

# %%
df = df[df['Amount'] != 'Amount']
df.sample(10)
# Out:
#            Datetime                                              Name    Type  \
# 639    Jan 23, 2024                              Paid to Verity Store   DEBIT
# 320    Mar 13, 2024  Paid to Kiit Hospitality PVT LTD - Food Court 06   DEBIT
# 1079  Sept 18, 2023                           Paid to Kiit Tanay Jain   DEBIT
# 741    Jan 12, 2024                          Paid to MANOJ KUMAR ROUT   DEBIT
# 425    Feb 25, 2024                             Paid to NARAYAN SETHI   DEBIT
# 1574   May 15, 2023                       Paid to PRADIPA KUMAR NAYAK   DEBIT
# 1351   Jul 16, 2023                                 Received from Dad  CREDIT
# 119    Apr 05, 2024                         Paid to FIRST CARE PHARMA   DEBIT
# 1570   May 15, 2023                                 Received from Mom  CREDIT
# 1340   Jul 16, 2023                     Paid to DEEPAK RANJAN PRADHAN   DEBIT
#
#      Amount
# 639      27
# 320      25
# 1079     65
# 741       7
# 425      80
# 1574    125
# 1351      1
# ...

# %%
df = df[df['Type'] != 'Type']
df.sample(10)
# Out:
#           Datetime                            Name    Type Amount
# 1562  May 16, 2023     Paid to Mr FANINDRA KRISHNA   DEBIT    169
# 1512  Jun 01, 2023  Paid to PURUSOTTAM KUMAR SINGH   DEBIT     60
# 1207  Aug 04, 2023      Paid to BAPUNI KUMAR SAHOO   DEBIT     80
# 1539  May 29, 2023              Paid to Hind store   DEBIT     20
# 900   Dec 01, 2023        Paid to MANOJ KUMAR ROUT   DEBIT     15
# 828   Dec 14, 2023        Received from ******7484  CREDIT    150
# 138   Apr 04, 2024                         Paid to   DEBIT  1,000
# 336   Mar 09, 2024    Received from Himanshu Gupta  CREDIT     45
# 766   Jan 08, 2024      Paid to Mr PRABHASH THAKUR   DEBIT     50
# 522   Feb 12, 2024          Paid to FRUIT SALAD 02   DEBIT     30

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'], format='%b %d, %Y', errors='coerce')
df.sample(10)
# Out:
#        Datetime                                   Name   Type Amount
# 386  2024-03-04  Paid to LITTLE CHEF FAMILY RESTAURANT  DEBIT    140
# 1211 2023-08-04           Paid to SUSANTA KUMAR BEHERA  DEBIT     30
# 441  2024-02-22                 Paid to HIMANSHU GUPTA  DEBIT    100
# 1473 2023-06-05           Paid to RAM LAL SO BHONA JAT  DEBIT    100
# 14   2024-04-28             Paid to Mr PRABHASH THAKUR  DEBIT    100
# 982  2023-11-16            Paid to NATANSH HEMANG SHAH  DEBIT    150
# 908  2023-11-30                         Paid to SWIGGY  DEBIT    196
# 1624 2023-05-12                Paid to Kiit Tanay Jain  DEBIT     10
# 608  2024-01-31                  Paid to Pradhan juice  DEBIT     20
# 1336 2023-07-17           Paid to Omm Sai Juice Center  DEBIT     40

# %%
df = df.dropna(subset=['Datetime'])
df.sample(10)
# Out:
#        Datetime                                               Name   Type  \
# 495  2024-02-15                              Paid to PRAKASH OMFED  DEBIT
# 801  2023-12-24                          Paid to Shree Enterprises  DEBIT
# 538  2024-02-09  Paid to Kalinga Institute of Industrial Techno...  DEBIT
# 1289 2023-07-23                                 Paid to Kiit Harsh  DEBIT
# 242  2024-03-21   Paid to KIIT Hospitality Pvt Ltd - Food Court 08  DEBIT
# 1434 2023-06-09                             Paid to Puja Chow Shop  DEBIT
# 219  2024-03-22                          Paid to SIMANCHAL BADATYA  DEBIT
# 877  2023-12-04              Paid to LITTLE CHEF FAMILY RESTAURANT  DEBIT
# 1465 2023-06-07                                 Paid to AVIJIT BAL  DEBIT
# 164  2024-03-28                           Paid to MANOJ KUMAR ROUT  DEBIT
#
#      Amount
# 495      20
# 801     450
# 538     450
# 1289    210
# 242     150
# 1434     80
# 219      12
# 877     277
# 1465     95
# 164      60

# %%
df = df[df['Name'] != 'Paid to']
df.sample(10)
# Out:
#        Datetime                                              Name    Type  \
# 1359 2023-07-13                                    Paid to Swiggy   DEBIT
# 367  2024-03-05  Paid to KIIT Hospitality Pvt Ltd - Food Court 08   DEBIT
# 1394 2023-06-27                                    Paid to SWIGGY   DEBIT
# 702  2024-01-17                                 Received from Mom  CREDIT
# 1293 2023-07-21                        Paid to manish kumar yadav   DEBIT
# 1512 2023-06-01                    Paid to PURUSOTTAM KUMAR SINGH   DEBIT
# 84   2024-04-08                           Paid to COURIER & XEROX   DEBIT
# 1340 2023-07-16                     Paid to DEEPAK RANJAN PRADHAN   DEBIT
# 1161 2023-08-10                           Paid to THE MUGS COFFEE   DEBIT
# 1231 2023-08-01             Paid to LITTLE CHEF FAMILY RESTAURANT   DEBIT
#
#      Amount
# 1359    240
# 367      80
# 1394    527
# 702   5,000
# 1293     45
# 1512     60
# 84       28
# 1340    267
# 1161     60
# 1231    200

# %%
df = df[df['Name'] != 'Received from']
df.sample(10)
# Out:
#        Datetime                                              Name    Type  \
# 1442 2023-06-09                              Paid to GOURAV SINGH   DEBIT
# 33   2024-04-22                                 Received from Mom  CREDIT
# 293  2024-03-16                         Paid to SIMANCHAL BADATYA   DEBIT
# 1149 2023-08-11                  Paid to Mr RUDRAMADHAB SAMANTARA   DEBIT
# 1328 2023-07-18                           Paid to THE MUGS COFFEE   DEBIT
# 725  2024-01-15                            Paid to Jaganath Store   DEBIT
# 974  2023-11-18  Paid to KIIT Hospitality Pvt Ltd - Food Court 08   DEBIT
# 962  2023-11-20                              Paid to AMBUJA SETHY   DEBIT
# 219  2024-03-22                         Paid to SIMANCHAL BADATYA   DEBIT
# 1305 2023-07-20                          Paid to MEDKART 24- FMCG   DEBIT
#
#      Amount
# 1442     47
# 33    2,000
# 293       6
# 1149     38
# 1328    110
# 725      75
# 974      80
# 962       5
# 219      12
# 1305     73

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 339 entries, 2 to 1644
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  339 non-null    datetime64[ns]
#  1   Name      339 non-null    object
#  2   Type      339 non-null    object
#  3   Amount    339 non-null    object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 13.2+ KB

# %%
def extract_name(row):
    if row['Type'] == 'DEBIT':
        return row['Name'].split('Paid to ')[-1]
    elif row['Type'] == 'CREDIT':
        return row['Name'].split('Received from ')[-1]
    else:
        return row['Name']
df["Name"] = df.apply(extract_name, axis=1)

# %%
df.sample(10)
# Out:
#        Datetime                                      Name    Type Amount
# 1500 2023-06-03                                    SWIGGY   DEBIT    261
# 285  2024-03-16                            TRIBENI SNACKS   DEBIT     10
# 460  2024-02-19             LITTLE CHEF FAMILY RESTAURANT   DEBIT    210
# 402  2024-03-01                          Kiit Harshvardan  CREDIT     70
# 242  2024-03-21  KIIT Hospitality Pvt Ltd - Food Court 08   DEBIT    150
# 297  2024-03-15  Kiit Hospitality PVT LTD - Food Court 06   DEBIT     25
# 103  2024-04-06                             ARPITA PARIDA   DEBIT     20
# 912  2023-11-30            Kiit Shubham Room Partner Kp15   DEBIT     35
# 10   2024-04-28                              Ganga Medico   DEBIT    116
# 1157 2023-08-10                           THE MUGS COFFEE   DEBIT     60

# %%
nan_values = df[df.isna().any(axis=1)]
print(nan_values)
# Out:
# Empty DataFrame
# Columns: [Datetime, Name, Type, Amount]
# Index: []

# %%
import calendar
df['Year'] = df['Datetime'].dt.year
df['Month'] = df['Datetime'].dt.month
df['Month'] = df['Month'].apply(lambda x: calendar.month_name[int(x)])
df['Date'] = df['Datetime'].dt.day
df['Day_of_Week'] = df['Datetime'].dt.day_name()

# %%
df.sample(10)
# Out:
#        Datetime                                      Name   Type Amount  Year  \
# 262  2024-03-19                             Sagnik Sarkar  DEBIT    500  2024
# 254  2024-03-20                           THE MUGS COFFEE  DEBIT    170  2024
# 805  2023-12-19                   Mr Jitendra Kumar Dubey  DEBIT    110  2023
# 1438 2023-06-09                          Akash matan shop  DEBIT     20  2023
# 1001 2023-10-13                                Rekha Devi  DEBIT    206  2023
# 1624 2023-05-12                           Kiit Tanay Jain  DEBIT     10  2023
# 892  2023-12-04                            MS AJAYA SUTAR  DEBIT     30  2023
# 92   2024-04-07  KIIT Hospitality Pvt Ltd - Food Court 08  DEBIT    115  2024
# 1589 2023-05-15                            BISWAJIT NAYAK  DEBIT    108  2023
# 596  2024-02-03                               RANJAN NAIK  DEBIT     50  2024
#
#          Month  Date Day_of_Week
# 262      March    19     Tuesday
# 254      March    20   Wednesday
# ...

# %%
df.to_csv('finaldf2.csv')

# %%
df.dtypes
# Out:
# Datetime       datetime64[ns]
# Name                   object
# Type                   object
# Amount                 object
# Year                    int32
# Month                  object
# Date                    int32
# Day_of_Week            object
# dtype: object

# %%
def extract_amount(row):
    if '.' in row['Amount']:
        return row['Amount'].split('.')[0]
    else:
        return row['Amount']
df['Amount'] = df.apply(extract_amount, axis=1)

# %%
df['Amount'] = df['Amount'].str.replace(',', '').astype(int)

# %% [markdown]
# # Data Analytics

# %%
total_debit = df[df['Type'] == 'DEBIT']['Amount'].sum()
total_credit = df[df['Type'] == 'CREDIT']['Amount'].sum()

print(f"Total Debit: {total_debit}")
print(f"Total Credit: {total_credit}")
# Out:
# Total Debit: 45496
# Total Credit: 37296

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=['Debit', 'Credit'], y=[total_debit, total_credit])
plt.xlabel('Transaction Type')
plt.ylabel('Total Amount')
plt.title('Total Debit vs Credit Amount')
plt.show()

# %%
transaction_types = df['Type'].value_counts()
plt.pie(transaction_types, labels=transaction_types.index, autopct='%1.1f%%')
plt.title('Pie Chart of Transaction Types')
plt.show()

# %%
df.set_index('Datetime', inplace=True)
df.resample('M')['Amount'].sum().plot(kind='line')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.title('Total Amount Transacted Over Time')
plt.show()
# Out:
# /var/folders/4s/5zz5l40s4_16nlwkkr1vz_4r0000gn/T/ipykernel_4553/1668573218.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample('M')['Amount'].sum().plot(kind='line')

# %%
sns.boxplot(x='Type', y='Amount', data=df)
plt.xlabel('Transaction Type')
plt.ylabel('Amount')
plt.title('Boxplot of Transaction Amounts by Type')
plt.show()

# %%
unique_names = df['Name'].unique()
for name in unique_names:
    print(name)
# Out:
# KRISHNA KUMAR
# RAKESH DRESSES
# Ganga Medico
# Mr PRABHASH THAKUR
# DHIRENDER KUMAR
# MANAS KUMAR NAYAK
# Kiit Shubham Room Partner Kp15
# Mom
# KIIT Hospitality Pvt Ltd - Food Court 08
# MANOJ KUMAR ROUT
# Kiit Harshvardan
# LITTLE CHEF FAMILY RESTAURANT
# Manasa Barclays
# MITA NAHAK
# SWASTIK COMPUTER
# COURIER & XEROX
# SANCHIT KANOJIA
# ARPITA PARIDA
# Rapido
# Jagannath Drug House
# FIRST CARE PHARMA
# Transfer to XXXXXX2282
# MOHIT KAUL
# Md Mafuz Sk
# Bajrang Fuels
# PARIDA BABU TEA STALL
# MEDKART 24- FMCG
# V2 Retail
# APOLLO PHARMACY
# DELHI CHAAT
# NIRET SANTOSH BADGIRE
# SIMANCHAL BADATYA
# Kiit Samridhi
# Ashutosh Jha
# THE MUGS COFFEE
# SANJAY KUMAR SAHOO
# Sagnik Sarkar
# SWAYAM SUBHAM SWAIN
# ZOMATO LIMITED
# TRIBENI SNACKS
# Kiit Hospitality PVT LTD - Food Court 06
# Patra snacks & grocery
# GOOGLE MART
# BAJARANGI STORE
# MEDKART 24
# Dad
# Patra variety store
# Himanshu Gupta
# Dominos Pizza
# MOHAN KUMAR MALLIK
# Bonfire Bakery K
# Kiit Dhruv
# KIMS C20
# Ashok
# ...

# %%
vijay_hotel_transactions = df[df['Name'] == 'Rapido']

vijay_hotel_transactions
# Out:
#               Name   Type  Amount  Year    Month  Date Day_of_Week
# Datetime
# 2024-04-06  Rapido  DEBIT      30  2024    April     6    Saturday
# 2024-01-21  Rapido  DEBIT      69  2024  January    21      Sunday
# 2024-01-19  Rapido  DEBIT      27  2024  January    19      Friday

# %%
if not vijay_hotel_transactions.empty:
    plt.figure(figsize=(10, 6))
    plt.plot(vijay_hotel_transactions.index, vijay_hotel_transactions['Amount'], marker='o')
    plt.xlabel('Date')
    plt.ylabel('Amount')
    plt.title('Transactions at Vijay Hotel')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("No transactions found for Vijay Hotel.")

# %%
credit_df = df[df['Amount'] > 0]
monthly_credit = credit_df.groupby('Month')['Amount'].sum().reset_index()
highest_credit_month = monthly_credit.loc[monthly_credit['Amount'].idxmax()]

print("Month with the highest credit:")
print(highest_credit_month)
# Out:
# Month with the highest credit:
# Month      July
# Amount    11782
# Name: 5, dtype: object

# %%
import matplotlib.pyplot as plt
monthly_data = df.groupby('Month')['Amount'].sum()
plt.figure(figsize=(10, 6))
plt.bar(monthly_data.index, monthly_data.values)
plt.xlabel('Month')
plt.ylabel('Total Amount')
plt.title('Total Amount Spent by Month')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
monthly_data = df.groupby('Month')['Amount'].sum()
colors = plt.cm.tab20c.colors[:len(monthly_data)]
plt.figure(figsize=(12, 6))
bars = plt.bar(monthly_data.index, monthly_data.values, color=colors, edgecolor='black')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Month', fontsize=12, fontweight='bold')
plt.ylabel('Total Amount', fontsize=12, fontweight='bold')
plt.title('Total Amount Spent by Month', fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.yticks(fontsize=10)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 20, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
transaction_types = df['Type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(transaction_types, labels=transaction_types.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Transaction Types')
plt.show()

# %%
transaction_types = df['Type'].value_counts()
colors = ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3']
plt.figure(figsize=(8, 8))
plt.pie(transaction_types, labels=transaction_types.index, autopct='%1.1f%%', startangle=90,
        colors=colors, shadow=True)
plt.title('Percentage of Transaction Types', pad=20, fontweight='bold', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Percentage of Transaction Types')

# %%
debit_data = df[df['Type'] == 'DEBIT']
top_debit_persons = debit_data.groupby('Name')['Amount'].sum().nlargest(5)

# %%
print(top_debit_persons)
# Out:
# Name
# Kiit Harshvardan                            2954
# LITTLE CHEF FAMILY RESTAURANT               2377
# SWIGGY                                      2191
# KIIT Hospitality Pvt Ltd - Food Court 08    2155
# FIRST CARE PHARMA                           1927
# Name: Amount, dtype: int64

# %%
daily_data = df.groupby('Date')['Amount'].sum()
plt.figure(figsize=(12, 6))
plt.plot(daily_data.index, daily_data.values, marker='o', linestyle='-', color='b')
plt.xlabel('Date', fontsize=12, fontweight='bold')
plt.ylabel('Total Amount', fontsize=12, fontweight='bold')
plt.title('Daily Total Amount Spent', fontsize=14, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.,
#          7000.]),
#  [Text(0, -1000.0, '−1000'),
#   Text(0, 0.0, '0'),
#   Text(0, 1000.0, '1000'),
#   Text(0, 2000.0, '2000'),
#   Text(0, 3000.0, '3000'),
#   Text(0, 4000.0, '4000'),
#   Text(0, 5000.0, '5000'),
#   Text(0, 6000.0, '6000'),
#   Text(0, 7000.0, '7000')])

# %%
day_of_week_data = df.groupby('Day_of_Week')['Amount'].sum()
plt.figure(figsize=(10, 6))
plt.bar(day_of_week_data.index, day_of_week_data.values)
plt.xlabel('Day of Week')
plt.ylabel('Total Amount')
plt.title('Total Amount Spent by Day of Week')
plt.show()

# %%
day_of_week_data = df.groupby('Day_of_Week')['Amount'].sum()
plt.figure(figsize=(10, 6))
plt.bar(day_of_week_data.index, day_of_week_data.values, color='skyblue', edgecolor='black')
plt.xlabel('Day of Week', fontsize=12, fontweight='bold')
plt.ylabel('Total Amount', fontsize=12, fontweight='bold')
plt.title('Total Amount Spent by Day of Week', fontsize=14, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
# Out:
# (array([    0.,  2500.,  5000.,  7500., 10000., 12500., 15000., 17500.,
#         20000., 22500.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 2500.0, '2500'),
#   Text(0, 5000.0, '5000'),
#   Text(0, 7500.0, '7500'),
#   Text(0, 10000.0, '10000'),
#   Text(0, 12500.0, '12500'),
#   Text(0, 15000.0, '15000'),
#   Text(0, 17500.0, '17500'),
#   Text(0, 20000.0, '20000'),
#   Text(0, 22500.0, '22500')])

# %%
import matplotlib.pyplot as plt

# Group by 'Name' and sum the 'Amount'
name_data = df.groupby('Name')['Amount'].sum().sort_values(ascending=False)

# Limit to Top 20 names to avoid clutter
top_n = 20
name_data = name_data.head(top_n)

# Plot with better spacing
plt.figure(figsize=(12, 6))
plt.bar(name_data.index, name_data.values, color='royalblue')

# Labels and Title
plt.xlabel('Name', fontsize=12)
plt.ylabel('Total Amount', fontsize=12)
plt.title(f'Total Amount Spent by Top {top_n} Names', fontsize=14)

# Rotate labels properly
plt.xticks(rotation=30, ha='right', fontsize=10)

# Add grid lines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show Plot
plt.show()

# %%
name_data = df.groupby('Name')['Amount'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
plt.bar(name_data.index, name_data.values, color='skyblue', edgecolor='black')
plt.xlabel('Name', fontsize=12, fontweight='bold')
plt.ylabel('Total Amount', fontsize=12, fontweight='bold')
plt.title('Total Amount Spent by Name', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
# Out:
# (array([    0.,  2500.,  5000.,  7500., 10000., 12500., 15000., 17500.,
#         20000., 22500.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 2500.0, '2500'),
#   Text(0, 5000.0, '5000'),
#   Text(0, 7500.0, '7500'),
#   Text(0, 10000.0, '10000'),
#   Text(0, 12500.0, '12500'),
#   Text(0, 15000.0, '15000'),
#   Text(0, 17500.0, '17500'),
#   Text(0, 20000.0, '20000'),
#   Text(0, 22500.0, '22500')])

# %%
yearly_data = df.groupby('Year')['Amount'].sum()
plt.figure(figsize=(10, 6))
plt.bar(yearly_data.index, yearly_data.values)
plt.xlabel('Year')
plt.ylabel('Total Amount')
plt.title('Total Amount Spent by Year')
plt.show()
